# %%
import cv2,os

data_path='F:\INTERNSHIP\Data Science Projects\Project 4 Face Mask Detection\dataset'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary

print(label_dict)
print(categories)
print(labels)
# Out:
# {'with mask': 0, 'without mask': 1}
# ['with mask', 'without mask']
# [0, 1]

# %%
img_size=100
data=[]
target=[]


for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)

        try:
            gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)           
            #Coverting the image into gray scale
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the gray scale into 100x100, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            target.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)

        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %%
import numpy as np

data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
target=np.array(target)

from keras.utils import np_utils

new_target=np_utils.to_categorical(target)

# %%
np.save('data',data)
np.save('target',new_target)

# %%
import numpy as np

data=np.load('data.npy')
target=np.load('target.npy')

#loading the save numpy arrays in the previous code

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint

# %%
model=Sequential()

model.add(Conv2D(200,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(100,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
model.add(Dropout(0.5))
#Flatten layer to stack the output convolutions from second convolution layer
model.add(Dense(50,activation='relu'))
#Dense layer of 64 neurons
model.add(Dense(2,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 200)       2000
#
#  activation (Activation)     (None, 98, 98, 200)       0
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 200)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 100)       180100
#
#  activation_1 (Activation)   (None, 47, 47, 100)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 100)      0
#  2D)
#
#  flatten (Flatten)           (None, 52900)             0
#
#  dropout (Dropout)           (None, 52900)             0
#
#  dense (Dense)               (None, 50)                2645050
#
#  dense_1 (Dense)             (None, 2)                 102
#
# =================================================================
# Total params: 2,827,252
# Trainable params: 2,827,252
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split

train_data,test_data,train_target,test_target=train_test_split(data,target,test_size=0.1)

# %%
checkpoint = ModelCheckpoint('model-{epoch:03d}.model',monitor='val_loss',verbose=0,save_best_only=True,mode='auto')
history=model.fit(train_data,train_target,epochs=20,callbacks=[checkpoint],validation_split=0.2)
# Out:
# Epoch 1/20
# 31/31 [==============================] - ETA: 0s - loss: 0.6898 - accuracy: 0.6030INFO:tensorflow:Assets written to: model-001.model\assets
# 31/31 [==============================] - 82s 2s/step - loss: 0.6898 - accuracy: 0.6030 - val_loss: 0.5844 - val_accuracy: 0.7137
# Epoch 2/20
# 31/31 [==============================] - ETA: 0s - loss: 0.4523 - accuracy: 0.7909INFO:tensorflow:Assets written to: model-002.model\assets
# 31/31 [==============================] - 71s 2s/step - loss: 0.4523 - accuracy: 0.7909 - val_loss: 0.4218 - val_accuracy: 0.7863
# Epoch 3/20
# 31/31 [==============================] - 65s 2s/step - loss: 0.2712 - accuracy: 0.8939 - val_loss: 0.5334 - val_accuracy: 0.7581
# Epoch 4/20
# 31/31 [==============================] - ETA: 0s - loss: 0.2077 - accuracy: 0.9212INFO:tensorflow:Assets written to: model-004.model\assets
# 31/31 [==============================] - 71s 2s/step - loss: 0.2077 - accuracy: 0.9212 - val_loss: 0.2342 - val_accuracy: 0.9315
# Epoch 5/20
# 31/31 [==============================] - 58s 2s/step - loss: 0.1259 - accuracy: 0.9525 - val_loss: 0.3898 - val_accuracy: 0.8589
# Epoch 6/20
# 31/31 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9586INFO:tensorflow:Assets written to: model-006.model\assets
# 31/31 [==============================] - 60s 2s/step - loss: 0.1193 - accuracy: 0.9586 - val_loss: 0.1808 - val_accuracy: 0.9274
# Epoch 7/20
# 31/31 [==============================] - 59s 2s/step - loss: 0.0693 - accuracy: 0.9788 - val_loss: 0.2149 - val_accuracy: 0.9274
# Epoch 8/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0413 - accuracy: 0.9879 - val_loss: 0.2577 - val_accuracy: 0.9395
# Epoch 9/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0521 - accuracy: 0.9808 - val_loss: 0.2735 - val_accuracy: 0.9234
# Epoch 10/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0463 - accuracy: 0.9828 - val_loss: 0.1849 - val_accuracy: 0.9435
# Epoch 11/20
# 31/31 [==============================] - 55s 2s/step - loss: 0.0416 - accuracy: 0.9828 - val_loss: 0.2172 - val_accuracy: 0.9395
# Epoch 12/20
# 31/31 [==============================] - 55s 2s/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 0.2107 - val_accuracy: 0.9516
# Epoch 13/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0170 - accuracy: 0.9939 - val_loss: 0.2806 - val_accuracy: 0.9355
# Epoch 14/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0188 - accuracy: 0.9909 - val_loss: 0.2609 - val_accuracy: 0.9435
# Epoch 15/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0250 - accuracy: 0.9879 - val_loss: 0.1864 - val_accuracy: 0.9395
# Epoch 16/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0336 - accuracy: 0.9848 - val_loss: 0.2710 - val_accuracy: 0.9315
# Epoch 17/20
# 31/31 [==============================] - 55s 2s/step - loss: 0.0302 - accuracy: 0.9909 - val_loss: 0.2176 - val_accuracy: 0.9476
# Epoch 18/20
# 31/31 [==============================] - 56s 2s/step - loss: 0.0243 - accuracy: 0.9919 - val_loss: 0.2312 - val_accuracy: 0.9435
# Epoch 19/20
# 31/31 [==============================] - 61s 2s/step - loss: 0.0351 - accuracy: 0.9848 - val_loss: 0.2895 - val_accuracy: 0.9435
# Epoch 20/20
# 31/31 [==============================] - 66s 2s/step - loss: 0.0142 - accuracy: 0.9939 - val_loss: 0.2392 - val_accuracy: 0.9476

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['loss'],'r',label='training loss')
plt.plot(history.history['val_loss'],label='validation loss')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'],'r',label='training accuracy')
plt.plot(history.history['val_accuracy'],label='validation accuracy')
plt.xlabel('# epochs')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
print(model.evaluate(test_data,test_target))
# Out:
# 5/5 [==============================] - 4s 672ms/step - loss: 0.1128 - accuracy: 0.9783
# [0.11280976235866547, 0.97826087474823]

# %%
from tensorflow.keras.models import load_model
import cv2
import numpy as np

# %%
model = load_model('model-017.model')

face_clsfr=cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

source=cv2.VideoCapture(0)

labels_dict={0:'MASK',1:'NO MASK'}
color_dict={0:(0,255,0),1:(0,0,255)}

# %%
while(True):

    ret,img = source.read()
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_clsfr.detectMultiScale(gray,scaleFactor=1.3,minNeighbors=5)  

    for (x,y,w,h) in faces:
    
        face_img=gray[y:y+w,x:x+w]
        resized=cv2.resize(face_img,(100,100))
        normalized=resized/255.0
        reshaped=np.reshape(normalized,(1,100,100,1))
        result=model.predict(reshaped)

        label=np.argmax(result,axis=1)[0]
      
        cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),color_dict[label],-1)
        cv2.putText(img, labels_dict[label], (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
        
        
    cv2.imshow('LIVE',img)
    key=cv2.waitKey(1)
    
    if(key==27):
        break
        
cv2.destroyAllWindows()
source.release()
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# File C:\Program Files\Python310\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\c_api_util.py:199, in tf_buffer(data)
#     198 try:
# --> 199   yield buf
#     200 finally:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:2690, in Operation.get_attr(self, name)
#    2689 with c_api_util.tf_buffer() as buf:
# -> 2690   pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2691   data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'range/start' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <module>
#      11 normalized=resized/255.0
#      12 reshaped=np.reshape(normalized,(1,100,100,1))
# ---> 13 result=model.predict(reshaped)
#      15 label=np.argmax(result,axis=1)[0]
#      17 cv2.rectangle(img,(x,y),(x+w,y+h),color_dict[label],2)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\training.py:1951, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1944   except ValueError:
#    1945     warnings.warn(
#    1946         'Using Model.predict with MultiWorkerMirroredStrategy or '
#    1947         'TPUStrategy and AutoShardPolicy.FILE might lead to out-of-order '
#    1948         'result. Consider setting it to AutoShardPolicy.DATA.',
#    1949         stacklevel=2)
# -> 1951 data_handler = data_adapter.get_data_handler(
#    1952     x=x,
#    1953     batch_size=batch_size,
#    1954     steps_per_epoch=steps,
#    1955     initial_epoch=0,
#    1956     epochs=1,
#    1957     max_queue_size=max_queue_size,
#    1958     workers=workers,
#    1959     use_multiprocessing=use_multiprocessing,
#    1960     model=self,
#    1961     steps_per_execution=self._steps_per_execution)
#    1963 # Container that configures and calls `tf.keras.Callback`s.
#    1964 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\data_adapter.py:1399, in get_data_handler(*args, **kwargs)
#    1397 if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1398   return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1399 return DataHandler(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\data_adapter.py:1149, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1146   self._steps_per_execution = steps_per_execution
#    1148 adapter_cls = select_data_adapter(x, y)
# -> 1149 self._adapter = adapter_cls(
#    1150     x,
#    1151     y,
#    1152     batch_size=batch_size,
#    1153     steps=steps_per_epoch,
#    1154     epochs=epochs - initial_epoch,
#    1155     sample_weights=sample_weight,
#    1156     shuffle=shuffle,
#    1157     max_queue_size=max_queue_size,
#    1158     workers=workers,
#    1159     use_multiprocessing=use_multiprocessing,
#    1160     distribution_strategy=tf.distribute.get_strategy(),
#    1161     model=model)
#    1163 strategy = tf.distribute.get_strategy()
#    1165 self._current_step = 0
#
# File ~\AppData\Roaming\Python\Python310\site-packages\keras\engine\data_adapter.py:292, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     286   return indices
#     288 # We prefetch a single element. Computing large permutations can take quite
#     289 # a while so we don't want to wait for prefetching over an epoch boundary to
#     290 # trigger the next permutation. On the other hand, too many simultaneous
#     291 # shuffles can contend on a hardware level and degrade all performance.
# --> 292 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     294 def slice_batch_indices(indices):
#     295   """Convert a Tensor of indices into a dataset of batched indices.
#     296
#     297   This step can be accomplished in several ways. The most natural is to
#    (...)
#     308     A Dataset of batched indices.
#     309   """
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:2016, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2013   if deterministic is not None and not DEBUG_MODE:
#    2014     warnings.warn("The `deterministic` argument has no effect unless the "
#    2015                   "`num_parallel_calls` argument is specified.")
# -> 2016   return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2017 else:
#    2018   return ParallelMapDataset(
#    2019       self,
#    2020       map_func,
#    (...)
#    2023       preserve_cardinality=True,
#    2024       name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:5191, in MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5189 self._use_inter_op_parallelism = use_inter_op_parallelism
#    5190 self._preserve_cardinality = preserve_cardinality
# -> 5191 self._map_func = structured_function.StructuredFunctionWrapper(
#    5192     map_func,
#    5193     self._transformation_name(),
#    5194     dataset=input_dataset,
#    5195     use_legacy_function=use_legacy_function)
#    5196 self._metadata = dataset_metadata_pb2.Metadata()
#    5197 if name:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:271, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     264       warnings.warn(
#     265           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     266           "option is set, this option does not apply to tf.data functions. "
#     267           "To force eager execution of tf.data functions, please use "
#     268           "`tf.data.experimental.enable_debug_mode()`.")
#     269     fn_factory = trace_tf_function(defun_kwargs)
# --> 271 self._function = fn_factory()
#     272 # There is no graph to add in eager mode.
#     273 add_to_graph &= not context.executing_eagerly()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:3070, in Function.get_concrete_function(self, *args, **kwargs)
#    3061 def get_concrete_function(self, *args, **kwargs):
#    3062   """Returns a `ConcreteFunction` specialized to inputs and execution context.
#    3063
#    3064   Args:
#    (...)
#    3068        or `tf.Tensor` or `tf.TensorSpec`.
#    3069   """
# -> 3070   graph_function = self._get_concrete_function_garbage_collected(
#    3071       *args, **kwargs)
#    3072   graph_function._garbage_collector.release()  # pylint: disable=protected-access
#    3073   return graph_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:3036, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3034   args, kwargs = None, None
#    3035 with self._lock:
# -> 3036   graph_function, _ = self._maybe_define_function(args, kwargs)
#    3037   seen_names = set()
#    3038   captured = object_identity.ObjectIdentitySet(
#    3039       graph_function.graph.internal_captures)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:3292, in Function._maybe_define_function(self, args, kwargs)
#    3288   return self._define_function_with_shape_relaxation(
#    3289       args, kwargs, flat_args, filtered_flat_args)
#    3291 self._function_cache.add_call_context(cache_key.call_context)
# -> 3292 graph_function = self._create_graph_function(args, kwargs)
#    3293 self._function_cache.add(cache_key, cache_key_deletion_observer,
#    3294                          graph_function)
#    3296 return graph_function, filtered_flat_args
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\function.py:3130, in Function._create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3125 missing_arg_names = [
#    3126     "%s_%d" % (arg, i) for i, arg in enumerate(missing_arg_names)
#    3127 ]
#    3128 arg_names = base_arg_names + missing_arg_names
#    3129 graph_function = ConcreteFunction(
# -> 3130     func_graph_module.func_graph_from_py_func(
#    3131         self._name,
#    3132         self._python_function,
#    3133         args,
#    3134         kwargs,
#    3135         self.input_signature,
#    3136         autograph=self._autograph,
#    3137         autograph_options=self._autograph_options,
#    3138         arg_names=arg_names,
#    3139         override_flat_arg_shapes=override_flat_arg_shapes,
#    3140         capture_by_value=self._capture_by_value),
#    3141     self._function_attributes,
#    3142     function_spec=self.function_spec,
#    3143     # Tell the ConcreteFunction to clean up its graph once it goes out of
#    3144     # scope. This is not the default behavior since it gets used in some
#    3145     # places (like Keras) where the FuncGraph lives longer than the
#    3146     # ConcreteFunction.
#    3147     shared_func_graph=False)
#    3148 return graph_function
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\func_graph.py:1053, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1050 else:
#    1051   deps_control_manager = ops.NullContextmanager()
# -> 1053 with func_graph.as_default(), deps_control_manager as deps_ctx:
#    1054   current_scope = variable_scope.get_variable_scope()
#    1055   default_use_resource = current_scope.use_resource
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\auto_control_deps.py:465, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     462 resource_inputs = set()
#     463 # Check for any resource inputs. If we find any, we update control_inputs
#     464 # and last_write_to_resource.
# --> 465 for inp, resource_type in _get_resource_inputs(op):
#     466   is_read = resource_type == ResourceType.READ_ONLY
#     467   input_id = ops.tensor_id(inp)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\auto_control_deps.py:663, in _get_resource_inputs(op)
#     661 def _get_resource_inputs(op):
#     662   """Returns an iterable of resources touched by this `op`."""
# --> 663   reads, writes = utils.get_read_write_resource_inputs(op)
#     664   saturated = False
#     665   while not saturated:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\auto_control_deps_utils.py:105, in get_read_write_resource_inputs(op)
#     102   return (reads, writes)
#     104 try:
# --> 105   read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106 except ValueError:
#     107   # Attr was not set. Add all resource inputs to `writes` and return.
#     108   writes.update(t for t in op.inputs if t.dtype == dtypes.resource)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:2689, in Operation.get_attr(self, name)
#    2687 fields = ("s", "i", "f", "b", "type", "shape", "tensor", "func")
#    2688 try:
# -> 2689   with c_api_util.tf_buffer() as buf:
#    2690     pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2691     data = pywrap_tf_session.TF_GetBuffer(buf)
#
# File C:\Program Files\Python310\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# KeyboardInterrupt:
